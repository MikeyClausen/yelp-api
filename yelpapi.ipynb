# %%
import json
from yelpapi import YelpAPI
import pandas as pd

# %%
with open('C:/Users/Mikey/Documents/keys/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
results = yelp_api.search_query(location='Baltimore, MD',
                                       term='Crab Cake')
print(type(results))
results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# # API CALLS

# %%
breakfast_0=yelp_api.search_query(location='Chicago, IL',
                                        term='Breakfast')
type(results)
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
breakfast0=pd.DataFrame(breakfast_0['businesses'])
breakfast0.head(2)
# Out:
#                        id                                  alias  \
# 0  cKZNbMvoqJaUe7n6lf6i7w  wildberry-pancakes-and-cafe-chicago-2
# 1  nnP8axu680aDGPdQ4TuSkA                   wake-n-bacon-chicago
#
#                           name  \
# 0  Wildberry Pancakes and Cafe
# 1                Wake ‘n Bacon
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/uMLcfB...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/rbp7mW...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/wildberry-pancakes-an...          9223
# 1  https://www.yelp.com/biz/wake-n-bacon-chicago?...           419
#
#                                           categories  rating  \
# 0  [{'alias': 'pancakes', 'title': 'Pancakes'}, {...     4.5
# 1  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
#
#                                        coordinates  \
# ...

# %%
breakfast_0['total']
# Out:
# 9600

# %%
breakfast_20=yelp_api.search_query(location='Chicago, IL',
                                        term='Breakfast',
                                  offset=20)

# %%
breakfast20=pd.DataFrame(breakfast_20['businesses'])
breakfast20.head(2)
# Out:
#                        id                             alias  \
# 0  cML-2BiYOVJ4zsCyMOMu6w           first-watch-oak-brook-3
# 1  oVXaqjkWgREI3Ft2-kSS6A  dalias-pancake-house-palos-hills
#
#                     name                                          image_url  \
# 0            First Watch  https://s3-media1.fl.yelpcdn.com/bphoto/pbDgkN...
# 1  Dalia's Pancake House  https://s3-media4.fl.yelpcdn.com/bphoto/dK08s7...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/first-watch-oak-brook...           222
# 1      False  https://www.yelp.com/biz/dalias-pancake-house-...            90
#
#                                           categories  rating  \
# 0  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 1  [{'alias': 'tradamerican', 'title': 'American ...     5.0
#
#                                          coordinates transactions price  \
# ...

# %%
all_breakfast = pd.concat([breakfast0, breakfast20],
                         ignore_index=True)
display(all_breakfast.head(3), all_breakfast.head(3))
# Out:
#                        id                                  alias  \
# 0  cKZNbMvoqJaUe7n6lf6i7w  wildberry-pancakes-and-cafe-chicago-2
# 1  nnP8axu680aDGPdQ4TuSkA                   wake-n-bacon-chicago
# 2  d7n-NmN_c65-8Gzz2FILGQ           cracked-on-milwaukee-chicago
#
#                           name  \
# 0  Wildberry Pancakes and Cafe
# 1                Wake ‘n Bacon
# 2         Cracked on Milwaukee
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/uMLcfB...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/rbp7mW...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/8gLZf5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/wildberry-pancakes-an...          9223
# 1  https://www.yelp.com/biz/wake-n-bacon-chicago?...           419
# 2  https://www.yelp.com/biz/cracked-on-milwaukee-...           218
#
# ...

# %%
all_breakfast.to_json(orient='records');
